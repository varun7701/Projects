# %% [markdown]
# # Lab 11: ODEs, Failure Rates, and Evolutionary Games

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np
import scipy as sp
import scipy.stats as st
from scipy.integrate import odeint
print ('Modules Imported!')
# Out:
# Modules Imported!

# %% [markdown]
# In this lab we're to going analyze evolutionary games using drift analysis. In order to do this, we first need to determine how to integrate ordinary differential equations. So, we begin with a brief exposure of how to achieve this in Python. While we're at it, we'll do a short exercise about failure rate functions.  Then we examine some evolutionary games, using both a stochastic model and a deterministic model, which involves the differential equations.

# %% [markdown]
# ## Integration of ODEs

# %% [markdown]
# This section gives an introdution to integrating ordinary differential equations (odes), with an application to the calculation of a CDF from a failure rate function.  If you recall from your math classes we can describe an ODE as the following:
#
# $\dot{y}=f(y),$
#
# where both $y$ and the function $f$ are vector valued, and $\dot{y}$ is shorthand for $\frac{dy}{dt}.$   The variables being vector valued simply implies that we could have a system of dependent one dimensional (1D) ODEs as opposed to just a single one dimensional variable.  Let's look at the following system:
#
# \begin{eqnarray*}
# \binom{\dot{y_0}}{\dot{y_1}} = \binom{2y_1-0.1y_0}{-y_0}
# \end{eqnarray*}
# with the initial condition $y_{init}=\binom{y_1(0)}{y_2(0)}=\binom{1}{1}.$
#
# Our goal in using Python is not to find a closed form solution to the ODE as you would have probably done in your math class, but to numerically integrate it and produce a graphical solution. In order to do this we use the odeint method from scipy.integrate. It takes a function with an initial value and specified times at which the solution is to be output. Internally, the numerical method will often use a much finer grid of time points to solve the ode -- but that is none of your concern.   The times you put in are the times at with the method needs to provide the values of the solution. Look how it is used below:

# %%
# Simple example integrating a 2d ordinary differential equation (ode) dy/dt=f(y,t) 
# Note that the odeint package is imported in the code at the beginning of this file.

# Function to integrate over
def f(y,t):    
    return np.array([2.*y[1]-.1*y[0],-y[0] ])

time=np.linspace(0.0,20.0,10000)   # The times at which the solution is output.
yinit=np.array([1.0,1.0])   # The initial condition
y=odeint(f,yinit,time)      

plt.plot(y[:,0],y[:,1])
plt.title('trajectory of y up to time 20')
plt.ylabel('y_1')
plt.xlabel('y_0')
# Out:
# Text(0.5, 0, 'y_0')

# %% [markdown]
# Typically in a plot like this you would add an arrow to indicate the direction of time in the graph. However, we know the initial state is $y_{init}=\binom{1}{1}.$ So as time increases, the trajectory moves concentrically inwards in a clockwise fashion. Depending on how much of differential equations you remember, this solution should make sense. The equation happens to have a linear form and can be written as $\dot y = Ay$ where
# $
# A=\left( \begin{array}{cc}  -0.1  &  2  \\  -1  & 0 \end{array} \right).
# $
# The eigenvalues of $A$ are complex with negative real parts, so we would expect a decaying oscillatory behavior. (If you didn't follow that, don't worry about it.)
#
# As a simple application of integrating a 1D (one-dimensional) ode, the following code calculates a CDF $F$ from its failure rate function $h.$ But first, let's look at some theory to remember what a failure rate function is. If we let $T$ be a positive random variable with a pdf $f_T$ then
# the failure rate function is defined by the following:
#
# $$h(t)=\lim_{\epsilon \to 0} \frac{P(t<T \leq t+\epsilon | T>t)}{\epsilon}$$
#
# Equivalently, an object having failure rate function $h$ means that for any $t > 0,$ given
# that the object is still working at time $t$, the probability it will fail in the next
# $\epsilon$ time units is $h(t)\epsilon + o(\epsilon)$.  (As usual, $o(\epsilon)$ represents an error term such that $o(\epsilon)/\epsilon \to 0$ as $\epsilon\to 0.$)  With a little bit more derivation (shown in Section 3.9 of your ECE 313 text), we can see that:
#
# $$h(t) = \frac{f_T(t)}{1-F_T(t)}$$
#
# Of course, the pdf $f_T$ is the derivative of the CDF $F_T$. Here's where your 1D ODE comes into play. Given a failure rate function, we want to be able to calculate the CDF. We can easily turn this into an ODE.
#
# $f_T(t) = (1-F_T(t))h(t)$
#
# Let $F_T(t) = y$ and  $f_T(t) = \frac{dy}{dt} = \dot{y}$, then:
#
# $\dot{y} = (1-y)h(t)$
#
# Now we have our differential equation set up and we can solve it by the same method used in the previous example. For the code below, we define a particular bathtub shaped failure rate function to model the lifetime of a component such as a hard disk drive. There is a high, but decreasing initial rate of failure, followed be a period with a very low rate failure, followed by an increasing rate of failure. You should be able to think of reasons why an object might exhibit this type of failure rate function. Notice that the CDF behaves as we would expect: always between 0 and 1, and reactive to $h(t)$.
#
# If you examine the ECE 313 notes you'll see another way to determine $F_T,$  namely, using
# $F_T(t) = 1- \exp \left( \int_o^t -h(s) ds \right)$.  The point here, though, is to get some practice using
# odeint, instead of using this formula.

# %%
# Calculation of CDF from its failure rate function, using dF/dt=(1-F(t))h(t)
from scipy.integrate import odeint

def h(t):   # h is the failure rate function with a bathtub shape
    if t<1:
        return 1-t
    elif t<3:
        return 0.0
    else:
        return np.sqrt(t-3)
    

def Fdot(y,t):    
    return (1-y)*h(t)

t_max=8.0  #  Select so that F(t_max) is very close to one
time=np.linspace(0.0,t_max,1000)
Finit=0.0
F=odeint(Fdot,Finit,time)

plt.plot(time,list(map(h,time)))
plt.text(4,h(4)+0.5, r'$h(t)$',fontsize=24) #Plots labels in the graph
plt.text(4,0.5, r'$F(t)$',fontsize=24) 

plt.plot(time,F)
plt.title('failure rate function $h$ and associated CDF, $F$')
plt.axis(ymin=0,ymax=2.0)
plt.ylabel('$h(t), F(t)$',fontsize=20)
plt.xlabel('$t$',fontsize=20)
# Out:
# Text(0.5, 0, '$t$')

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 1:</SPAN>** Using the information on failure rate functions and the example above, do the following:
# <ol>
# <li> Write code that, given the failure rate function of a random variable $T$, computes the mean lifetime, $E[T].$  Use this code to determine the mean lifetime for the example given above.  (Hint: An easy way to do this problem is to use the area rule for expectations. Since $T$ is nonnegative, the area rule for expectations gives $E[T]=\int_0^\infty(1-F(t)) dt.$
# The integral $\int_0^\infty (1-F(t)) dt$ is approximately equal to
# $\int_0^{t_{max}} (1-F(t)) dt,$  which, by the definition of Riemann integration, is approximately equal to
# $h \sum_{i=1}^{1000} (1-F(h_i)) $ where $h=t_{max}/1000.$  Basically the code above returns the samples $F(h_i)$ so all you need to do is subtract these values from 1, sum them up and multiply by $h$.)
# <li> What happens to $E[T]$ if the failure rate function is doubled for all time? Print out the new value of $E[T]$.
# </ol>

# %%
# Your code here
# Calculation of CDF from its failure rate function, using dF/dt=(1-F(t))h(t)
print('Question 1:')
from scipy.integrate import odeint

def h(t):   # h is the failure rate function with a bathtub shape
    if t<1:
        return 1-t
    elif t<3:
        return 0.0
    else:
        return np.sqrt(t-3)
    

def Fdot(y,t):    
    return (1-y)*h(t)

t_max=8.0  #  Select so that F(t_max) is very close to one
time=np.linspace(0.0,t_max,1000)
Finit=0.0
F=odeint(Fdot,Finit,time)

expected = 0.0
for i in range(1000):
    expected = expected + (1-F[i])
expected = expected * (t_max/1000.)
print ('The mean/expected lifetime is: ',expected)
# Out:
# Question 1:
# The mean/expected lifetime is:  [2.65652422]

# %%
# Your code here
# Calculation of CDF from its failure rate function, using dF/dt=(1-F(t))h(t)
print('Question 2:')
from scipy.integrate import odeint

def h(t):   # h is the failure rate function with a bathtub shape
    if t<1:
        return 2-2*t
    elif t<3:
        return 0.0
    else:
        return 2*np.sqrt(t-3)
    

def Fdot(y,t):    
    return (1-y)*h(t)

t_max=8.0  #  Select so that F(t_max) is very close to one
time=np.linspace(0.0,t_max,1000)
Finit=0.0
F=odeint(Fdot,Finit,time)

expected = 0.0
for i in range(1000):
    expected = expected + (1-F[i])
expected = expected * (t_max/1000.)
print ('The mean/expected lifetime is: ',expected)
# Out:
# Question 2:
# The mean/expected lifetime is:  [1.55044486]

# %% [markdown]
# __Answer:__ (Your answer here)

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 1</SPAN>**

# %% [markdown]
# ## Evolutionary games (replicator dynamics):

# %% [markdown]
# Consider a population of individuals, where each individual is of some type.  Suppose individuals have occasional pairwise encounters.  During an encounter the two individuals involved play a two player symmetric game in which the strategies are the types of the individuals.   As a result of the encounter, each of the two individuals produces a number of offspring of its same type, with the number being determined by a fitess table or, equivalently, a fitness matrix.   For example, consider a population of crickets such that each cricket is either small or large.   If two small crickets meet each other then they each spawn five more small crickets.  If a small cricket encounters a large cricket then the small cricket spawns one more small cricket and the large cricket spawns eight new large crickets.   If two large crickets meet then each of them spawns three new large crickets.  We can summarize these outcomes using the following table:
# $$\begin{array}{c|cc}  & small & large  \\ \hline
#     small & 5 & 1  \\
#     large & 8 & 3
#     \end{array}$$
# or by a fitness matrix
# $$F=\left( \begin{array}{cc}  5 & 1 \\ 8 & 3  \end{array}\right).$$
# Associating 0 with "small" and 1 with "large,"  we see that if a type i individual encounters a type j individual, then the type i individual spawns F[i,j] new individuals of type i, and the type j individual spawns F[j,i] new individuals of type j. Below is a stochastic simulation for this game where we start with a population of four small crickets and four large crickets. It may be a useful exercise for you to think of how the values for $a$ and $b$ were created.

# %%
# Stochastic simulation of replicator dynamics for cricket game

F=np.array([[5,1],[8,3]])  # fitness matrix

n=np.array([4,4])  #[number of small crickets, number of large crickets], initialized
print ("                                   State      Fractions of each type")
print ("Initially                        ", n, "      ", n/1./np.sum(n))

T = 1000 #total number of encounters

for k in range(T):   # k tracks number of encounters
    a=n[0]*(n[0]-1.0)/((n[0]+n[1])*(n[0]+n[1]-1))  # probability both players are type 0
    b=2*n[0]*n[1]/((n[0]+n[1])*(n[0]+n[1]-1.0))  # probability one player of each type
    U=np.random.rand()
    if U<=a:
        n+=[2*F[0,0],0]
        print ("Round",k+1,"two small crickets meet ", n, n/1./np.sum(n))
    elif a<U<=a+b:
        n+=[F[0,1],F[1,0]]
        print ("Round",k+1,"a small meets a large   ", n, n/1./np.sum(n))
    else:
        n+=[0,2*F[1,1]]
        print ("Round",k+1,"two large crickets meet ", n, n/1./np.sum(n))
# Out:
#                                    State      Fractions of each type
# Initially                         [4 4]        [0.5 0.5]
# Round 1 two small crickets meet  [14  4] [0.77777778 0.22222222]
# Round 2 two small crickets meet  [24  4] [0.85714286 0.14285714]
# Round 3 two small crickets meet  [34  4] [0.89473684 0.10526316]
# Round 4 two small crickets meet  [44  4] [0.91666667 0.08333333]
# Round 5 two small crickets meet  [54  4] [0.93103448 0.06896552]
# Round 6 two small crickets meet  [64  4] [0.94117647 0.05882353]
# Round 7 two small crickets meet  [74  4] [0.94871795 0.05128205]
# Round 8 two small crickets meet  [84  4] [0.95454545 0.04545455]
# Round 9 two small crickets meet  [94  4] [0.95918367 0.04081633]
# Round 10 two small crickets meet  [104   4] [0.96296296 0.03703704]
# Round 11 two small crickets meet  [114   4] [0.96610169 0.03389831]
# Round 12 two small crickets meet  [124   4] [0.96875 0.03125]
# Round 13 two small crickets meet  [134   4] [0.97101449 0.02898551]
# Round 14 two small crickets meet  [144   4] [0.97297297 0.02702703]
# Round 15 two small crickets meet  [154   4] [0.97468354 0.02531646]
# Round 16 a small meets a large    [155  12] [0.92814371 0.07185629]
# Round 17 a small meets a large    [156  20] [0.88636364 0.11363636]
# Round 18 two small crickets meet  [166  20] [0.89247312 0.10752688]
# Round 19 a small meets a large    [167  28] [0.85641026 0.14358974]
# Round 20 two small crickets meet  [177  28] [0.86341463 0.13658537]
# Round 21 two small crickets meet  [187  28] [0.86976744 0.13023256]
# Round 22 two small crickets meet  [197  28] [0.87555556 0.12444444]
# Round 23 two small crickets meet  [207  28] [0.88085106 0.11914894]
# Round 24 two small crickets meet  [217  28] [0.88571429 0.11428571]
# Round 25 two small crickets meet  [227  28] [0.89019608 0.10980392]
# Round 26 two small crickets meet  [237  28] [0.89433962 0.10566038]
# Round 27 a small meets a large    [238  36] [0.86861314 0.13138686]
# Round 28 two small crickets meet  [248  36] [0.87323944 0.12676056]
# Round 29 two small crickets meet  [258  36] [0.87755102 0.12244898]
# Round 30 a small meets a large    [259  44] [0.85478548 0.14521452]
# Round 31 two small crickets meet  [269  44] [0.85942492 0.14057508]
# Round 32 two small crickets meet  [279  44] [0.86377709 0.13622291]
# Round 33 a small meets a large    [280  52] [0.84337349 0.15662651]
# Round 34 two small crickets meet  [290  52] [0.84795322 0.15204678]
# Round 35 two small crickets meet  [300  52] [0.85227273 0.14772727]
# Round 36 two large crickets meet  [300  58] [0.83798883 0.16201117]
# Round 37 two small crickets meet  [310  58] [0.8423913 0.1576087]
# Round 38 two small crickets meet  [320  58] [0.84656085 0.15343915]
# Round 39 two small crickets meet  [330  58] [0.85051546 0.14948454]
# Round 40 two small crickets meet  [340  58] [0.85427136 0.14572864]
# Round 41 a small meets a large    [341  66] [0.83783784 0.16216216]
# Round 42 a small meets a large    [342  74] [0.82211538 0.17788462]
# Round 43 two small crickets meet  [352  74] [0.82629108 0.17370892]
# Round 44 two small crickets meet  [362  74] [0.83027523 0.16972477]
# Round 45 two small crickets meet  [372  74] [0.83408072 0.16591928]
# Round 46 two small crickets meet  [382  74] [0.8377193 0.1622807]
# Round 47 a small meets a large    [383  82] [0.82365591 0.17634409]
# Round 48 two small crickets meet  [393  82] [0.82736842 0.17263158]
# Round 49 two small crickets meet  [403  82] [0.83092784 0.16907216]
# Round 50 a small meets a large    [404  90] [0.81781377 0.18218623]
# Round 51 two small crickets meet  [414  90] [0.82142857 0.17857143]
# Round 52 two small crickets meet  [424  90] [0.82490272 0.17509728]
# Round 53 two small crickets meet  [434  90] [0.82824427 0.17175573]
# Round 54 two small crickets meet  [444  90] [0.83146067 0.16853933]
# Round 55 a small meets a large    [445  98] [0.81952118 0.18047882]
# Round 56 a small meets a large    [446 106] [0.80797101 0.19202899]
# Round 57 two small crickets meet  [456 106] [0.8113879 0.1886121]
# Round 58 two small crickets meet  [466 106] [0.81468531 0.18531469]
# Round 59 a small meets a large    [467 114] [0.80378657 0.19621343]
# Round 60 two small crickets meet  [477 114] [0.8071066 0.1928934]
# Round 61 two small crickets meet  [487 114] [0.81031614 0.18968386]
# Round 62 two small crickets meet  [497 114] [0.81342062 0.18657938]
# Round 63 two small crickets meet  [507 114] [0.81642512 0.18357488]
# Round 64 a small meets a large    [508 122] [0.80634921 0.19365079]
# Round 65 a small meets a large    [509 130] [0.79655712 0.20344288]
# Round 66 a small meets a large    [510 138] [0.78703704 0.21296296]
# Round 67 a small meets a large    [511 146] [0.77777778 0.22222222]
# Round 68 a small meets a large    [512 154] [0.76876877 0.23123123]
# Round 69 a small meets a large    [513 162] [0.76 0.24]
# Round 70 two small crickets meet  [523 162] [0.76350365 0.23649635]
# Round 71 two small crickets meet  [533 162] [0.76690647 0.23309353]
# Round 72 a small meets a large    [534 170] [0.75852273 0.24147727]
# Round 73 a small meets a large    [535 178] [0.75035063 0.24964937]
# Round 74 two small crickets meet  [545 178] [0.7538036 0.2461964]
# Round 75 a small meets a large    [546 186] [0.74590164 0.25409836]
# Round 76 a small meets a large    [547 194] [0.73819163 0.26180837]
# Round 77 two small crickets meet  [557 194] [0.74167776 0.25832224]
# Round 78 two small crickets meet  [567 194] [0.74507227 0.25492773]
# Round 79 two small crickets meet  [577 194] [0.74837873 0.25162127]
# Round 80 two small crickets meet  [587 194] [0.75160051 0.24839949]
# Round 81 a small meets a large    [588 202] [0.7443038 0.2556962]
# Round 82 two small crickets meet  [598 202] [0.7475 0.2525]
# Round 83 a small meets a large    [599 210] [0.74042027 0.25957973]
# Round 84 two small crickets meet  [609 210] [0.74358974 0.25641026]
# Round 85 two small crickets meet  [619 210] [0.74668275 0.25331725]
# Round 86 a small meets a large    [620 218] [0.7398568 0.2601432]
# Round 87 two small crickets meet  [630 218] [0.74292453 0.25707547]
# Round 88 two small crickets meet  [640 218] [0.74592075 0.25407925]
# Round 89 two small crickets meet  [650 218] [0.74884793 0.25115207]
# Round 90 two small crickets meet  [660 218] [0.75170843 0.24829157]
# Round 91 a small meets a large    [661 226] [0.74520857 0.25479143]
# Round 92 two small crickets meet  [671 226] [0.74804905 0.25195095]
# Round 93 a small meets a large    [672 234] [0.74172185 0.25827815]
# Round 94 a small meets a large    [673 242] [0.73551913 0.26448087]
# Round 95 a small meets a large    [674 250] [0.72943723 0.27056277]
# Round 96 two small crickets meet  [684 250] [0.73233405 0.26766595]
# Round 97 two small crickets meet  [694 250] [0.73516949 0.26483051]
# Round 98 two small crickets meet  [704 250] [0.73794549 0.26205451]
# Round 99 a small meets a large    [705 258] [0.73208723 0.26791277]
# Round 100 a small meets a large    [706 266] [0.72633745 0.27366255]
# Round 101 two small crickets meet  [716 266] [0.72912424 0.27087576]
# Round 102 two small crickets meet  [726 266] [0.73185484 0.26814516]
# Round 103 a small meets a large    [727 274] [0.72627373 0.27372627]
# Round 104 two large crickets meet  [727 280] [0.72194638 0.27805362]
# Round 105 a small meets a large    [728 288] [0.71653543 0.28346457]
# Round 106 two small crickets meet  [738 288] [0.71929825 0.28070175]
# Round 107 two large crickets meet  [738 294] [0.71511628 0.28488372]
# Round 108 a small meets a large    [739 302] [0.70989433 0.29010567]
# Round 109 a small meets a large    [740 310] [0.7047619 0.2952381]
# Round 110 two small crickets meet  [750 310] [0.70754717 0.29245283]
# Round 111 two small crickets meet  [760 310] [0.71028037 0.28971963]
# Round 112 two small crickets meet  [770 310] [0.71296296 0.28703704]
# Round 113 two large crickets meet  [770 316] [0.70902394 0.29097606]
# Round 114 two small crickets meet  [780 316] [0.71167883 0.28832117]
# Round 115 two small crickets meet  [790 316] [0.71428571 0.28571429]
# Round 116 a small meets a large    [791 324] [0.70941704 0.29058296]
# Round 117 two small crickets meet  [801 324] [0.712 0.288]
# Round 118 two small crickets meet  [811 324] [0.71453744 0.28546256]
# Round 119 two small crickets meet  [821 324] [0.71703057 0.28296943]
# Round 120 a small meets a large    [822 332] [0.71230503 0.28769497]
# Round 121 a small meets a large    [823 340] [0.70765262 0.29234738]
# Round 122 two large crickets meet  [823 346] [0.70402053 0.29597947]
# Round 123 two small crickets meet  [833 346] [0.70653096 0.29346904]
# Round 124 a small meets a large    [834 354] [0.7020202 0.2979798]
# Round 125 a small meets a large    [835 362] [0.69757728 0.30242272]
# Round 126 two large crickets meet  [835 368] [0.69409809 0.30590191]
# Round 127 two large crickets meet  [835 374] [0.69065343 0.30934657]
# Round 128 a small meets a large    [836 382] [0.6863711 0.3136289]
# Round 129 a small meets a large    [837 390] [0.68215159 0.31784841]
# Round 130 two small crickets meet  [847 390] [0.6847211 0.3152789]
# Round 131 two small crickets meet  [857 390] [0.6872494 0.3127506]
# Round 132 a small meets a large    [858 398] [0.68312102 0.31687898]
# Round 133 a small meets a large    [859 406] [0.67905138 0.32094862]
# Round 134 a small meets a large    [860 414] [0.67503925 0.32496075]
# Round 135 two small crickets meet  [870 414] [0.67757009 0.32242991]
# Round 136 a small meets a large    [871 422] [0.67362722 0.32637278]
# Round 137 a small meets a large    [872 430] [0.66973886 0.33026114]
# Round 138 two small crickets meet  [882 430] [0.6722561 0.3277439]
# Round 139 a small meets a large    [883 438] [0.66843301 0.33156699]
# Round 140 a small meets a large    [884 446] [0.66466165 0.33533835]
# Round 141 a small meets a large    [885 454] [0.660941 0.339059]
# Round 142 two large crickets meet  [885 460] [0.65799257 0.34200743]
# Round 143 a small meets a large    [886 468] [0.65435746 0.34564254]
# Round 144 a small meets a large    [887 476] [0.65077036 0.34922964]
# Round 145 two small crickets meet  [897 476] [0.65331391 0.34668609]
# Round 146 a small meets a large    [898 484] [0.64978292 0.35021708]
# Round 147 two large crickets meet  [898 490] [0.64697406 0.35302594]
# Round 148 a small meets a large    [899 498] [0.64352183 0.35647817]
# Round 149 two small crickets meet  [909 498] [0.64605544 0.35394456]
# Round 150 two small crickets meet  [919 498] [0.64855328 0.35144672]
# Round 151 a small meets a large    [920 506] [0.64516129 0.35483871]
# Round 152 a small meets a large    [921 514] [0.64181185 0.35818815]
# Round 153 two small crickets meet  [931 514] [0.64429066 0.35570934]
# Round 154 two small crickets meet  [941 514] [0.6467354 0.3532646]
# Round 155 two large crickets meet  [941 520] [0.6440794 0.3559206]
# Round 156 a small meets a large    [942 528] [0.64081633 0.35918367]
# Round 157 two large crickets meet  [942 534] [0.63821138 0.36178862]
# Round 158 a small meets a large    [943 542] [0.63501684 0.36498316]
# Round 159 two small crickets meet  [953 542] [0.63745819 0.36254181]
# Round 160 a small meets a large    [954 550] [0.63430851 0.36569149]
# Round 161 two small crickets meet  [964 550] [0.63672391 0.36327609]
# Round 162 two small crickets meet  [974 550] [0.63910761 0.36089239]
# Round 163 two large crickets meet  [974 556] [0.63660131 0.36339869]
# Round 164 two small crickets meet  [984 556] [0.63896104 0.36103896]
# Round 165 a small meets a large    [985 564] [0.63589413 0.36410587]
# Round 166 a small meets a large    [986 572] [0.63286264 0.36713736]
# Round 167 two large crickets meet  [986 578] [0.63043478 0.36956522]
# Round 168 two large crickets meet  [986 584] [0.62802548 0.37197452]
# Round 169 a small meets a large    [987 592] [0.62507916 0.37492084]
# Round 170 two small crickets meet  [997 592] [0.62743864 0.37256136]
# Round 171 a small meets a large    [998 600] [0.62453066 0.37546934]
# Round 172 a small meets a large    [999 608] [0.62165526 0.37834474]
# Round 173 a small meets a large    [1000  616] [0.61881188 0.38118812]
# Round 174 a small meets a large    [1001  624] [0.616 0.384]
# Round 175 a small meets a large    [1002  632] [0.61321909 0.38678091]
# Round 176 two small crickets meet  [1012  632] [0.61557178 0.38442822]
# Round 177 two large crickets meet  [1012  638] [0.61333333 0.38666667]
# Round 178 two large crickets meet  [1012  644] [0.61111111 0.38888889]
# Round 179 a small meets a large    [1013  652] [0.60840841 0.39159159]
# Round 180 a small meets a large    [1014  660] [0.60573477 0.39426523]
# Round 181 two small crickets meet  [1024  660] [0.60807601 0.39192399]
# Round 182 a small meets a large    [1025  668] [0.60543414 0.39456586]
# Round 183 a small meets a large    [1026  676] [0.60282021 0.39717979]
# Round 184 two large crickets meet  [1026  682] [0.60070258 0.39929742]
# Round 185 a small meets a large    [1027  690] [0.59813628 0.40186372]
# Round 186 a small meets a large    [1028  698] [0.59559676 0.40440324]
# Round 187 two small crickets meet  [1038  698] [0.59792627 0.40207373]
# Round 188 two small crickets meet  [1048  698] [0.6002291 0.3997709]
# Round 189 two small crickets meet  [1058  698] [0.60250569 0.39749431]
# Round 190 a small meets a large    [1059  706] [0.6 0.4]
# Round 191 two large crickets meet  [1059  712] [0.59796725 0.40203275]
# Round 192 two small crickets meet  [1069  712] [0.60022459 0.39977541]
# Round 193 a small meets a large    [1070  720] [0.59776536 0.40223464]
# Round 194 a small meets a large    [1071  728] [0.59533074 0.40466926]
# Round 195 a small meets a large    [1072  736] [0.59292035 0.40707965]
# Round 196 two small crickets meet  [1082  736] [0.59515952 0.40484048]
# Round 197 two small crickets meet  [1092  736] [0.59737418 0.40262582]
# Round 198 two large crickets meet  [1092  742] [0.59541985 0.40458015]
# Round 199 a small meets a large    [1093  750] [0.5930548 0.4069452]
# Round 200 two small crickets meet  [1103  750] [0.59525094 0.40474906]
# Round 201 two small crickets meet  [1113  750] [0.59742351 0.40257649]
# Round 202 a small meets a large    [1114  758] [0.59508547 0.40491453]
# Round 203 two large crickets meet  [1114  764] [0.59318424 0.40681576]
# Round 204 a small meets a large    [1115  772] [0.590885 0.409115]
# Round 205 a small meets a large    [1116  780] [0.58860759 0.41139241]
# Round 206 two small crickets meet  [1126  780] [0.590766 0.409234]
# Round 207 two small crickets meet  [1136  780] [0.59290188 0.40709812]
# Round 208 a small meets a large    [1137  788] [0.59064935 0.40935065]
# Round 209 a small meets a large    [1138  796] [0.58841779 0.41158221]
# Round 210 a small meets a large    [1139  804] [0.5862069 0.4137931]
# Round 211 a small meets a large    [1140  812] [0.58401639 0.41598361]
# Round 212 two small crickets meet  [1150  812] [0.5861366 0.4138634]
# Round 213 a small meets a large    [1151  820] [0.58396753 0.41603247]
# Round 214 a small meets a large    [1152  828] [0.58181818 0.41818182]
# Round 215 two small crickets meet  [1162  828] [0.5839196 0.4160804]
# Round 216 two small crickets meet  [1172  828] [0.586 0.414]
# Round 217 a small meets a large    [1173  836] [0.58387257 0.41612743]
# Round 218 a small meets a large    [1174  844] [0.58176412 0.41823588]
# Round 219 a small meets a large    [1175  852] [0.5796744 0.4203256]
# Round 220 a small meets a large    [1176  860] [0.57760314 0.42239686]
# Round 221 a small meets a large    [1177  868] [0.57555012 0.42444988]
# Round 222 two small crickets meet  [1187  868] [0.57761557 0.42238443]
# Round 223 two small crickets meet  [1197  868] [0.57966102 0.42033898]
# Round 224 a small meets a large    [1198  876] [0.57762777 0.42237223]
# Round 225 two small crickets meet  [1208  876] [0.57965451 0.42034549]
# Round 226 two large crickets meet  [1208  882] [0.57799043 0.42200957]
# Round 227 a small meets a large    [1209  890] [0.57598857 0.42401143]
# Round 228 two large crickets meet  [1209  896] [0.57434679 0.42565321]
# Round 229 a small meets a large    [1210  904] [0.57237465 0.42762535]
# Round 230 two large crickets meet  [1210  910] [0.57075472 0.42924528]
# Round 231 two large crickets meet  [1210  916] [0.56914393 0.43085607]
# Round 232 a small meets a large    [1211  924] [0.56721311 0.43278689]
# Round 233 two large crickets meet  [1211  930] [0.56562354 0.43437646]
# Round 234 a small meets a large    [1212  938] [0.56372093 0.43627907]
# Round 235 a small meets a large    [1213  946] [0.56183418 0.43816582]
# Round 236 two small crickets meet  [1223  946] [0.56385431 0.43614569]
# Round 237 a small meets a large    [1224  954] [0.56198347 0.43801653]
# Round 238 two small crickets meet  [1234  954] [0.56398537 0.43601463]
# Round 239 a small meets a large    [1235  962] [0.56213018 0.43786982]
# Round 240 a small meets a large    [1236  970] [0.56029012 0.43970988]
# Round 241 two large crickets meet  [1236  976] [0.55877034 0.44122966]
# Round 242 a small meets a large    [1237  984] [0.55695633 0.44304367]
# Round 243 two small crickets meet  [1247  984] [0.55894218 0.44105782]
# Round 244 two small crickets meet  [1257  984] [0.56091031 0.43908969]
# Round 245 a small meets a large    [1258  992] [0.55911111 0.44088889]
# Round 246 a small meets a large    [1259 1000] [0.55732625 0.44267375]
# Round 247 a small meets a large    [1260 1008] [0.55555556 0.44444444]
# Round 248 a small meets a large    [1261 1016] [0.55379886 0.44620114]
# Round 249 two small crickets meet  [1271 1016] [0.55574989 0.44425011]
# Round 250 a small meets a large    [1272 1024] [0.55400697 0.44599303]
# Round 251 two small crickets meet  [1282 1024] [0.55594102 0.44405898]
# Round 252 two large crickets meet  [1282 1030] [0.55449827 0.44550173]
# Round 253 two small crickets meet  [1292 1030] [0.55641688 0.44358312]
# Round 254 two large crickets meet  [1292 1036] [0.55498282 0.44501718]
# Round 255 two small crickets meet  [1302 1036] [0.55688623 0.44311377]
# Round 256 a small meets a large    [1303 1044] [0.55517682 0.44482318]
# Round 257 a small meets a large    [1304 1052] [0.55348048 0.44651952]
# Round 258 a small meets a large    [1305 1060] [0.55179704 0.44820296]
# Round 259 a small meets a large    [1306 1068] [0.55012637 0.44987363]
# Round 260 two small crickets meet  [1316 1068] [0.55201342 0.44798658]
# Round 261 a small meets a large    [1317 1076] [0.5503552 0.4496448]
# Round 262 a small meets a large    [1318 1084] [0.54870941 0.45129059]
# Round 263 two small crickets meet  [1328 1084] [0.55058043 0.44941957]
# Round 264 two large crickets meet  [1328 1090] [0.54921423 0.45078577]
# Round 265 a small meets a large    [1329 1098] [0.54758962 0.45241038]
# Round 266 a small meets a large    [1330 1106] [0.54597701 0.45402299]
# Round 267 a small meets a large    [1331 1114] [0.54437628 0.45562372]
# Round 268 a small meets a large    [1332 1122] [0.54278729 0.45721271]
# Round 269 a small meets a large    [1333 1130] [0.54120991 0.45879009]
# Round 270 a small meets a large    [1334 1138] [0.53964401 0.46035599]
# Round 271 two large crickets meet  [1334 1144] [0.53833737 0.46166263]
# Round 272 a small meets a large    [1335 1152] [0.53679131 0.46320869]
# Round 273 two large crickets meet  [1335 1158] [0.5354994 0.4645006]
# Round 274 a small meets a large    [1336 1166] [0.53397282 0.46602718]
# Round 275 a small meets a large    [1337 1174] [0.53245719 0.46754281]
# Round 276 two large crickets meet  [1337 1180] [0.53118792 0.46881208]
# Round 277 a small meets a large    [1338 1188] [0.52969121 0.47030879]
# Round 278 a small meets a large    [1339 1196] [0.52820513 0.47179487]
# Round 279 a small meets a large    [1340 1204] [0.52672956 0.47327044]
# Round 280 two small crickets meet  [1350 1204] [0.52858262 0.47141738]
# Round 281 two large crickets meet  [1350 1210] [0.52734375 0.47265625]
# Round 282 a small meets a large    [1351 1218] [0.52588556 0.47411444]
# Round 283 a small meets a large    [1352 1226] [0.52443755 0.47556245]
# Round 284 two small crickets meet  [1362 1226] [0.52627512 0.47372488]
# Round 285 two small crickets meet  [1372 1226] [0.52809854 0.47190146]
# Round 286 a small meets a large    [1373 1234] [0.526659 0.473341]
# Round 287 two small crickets meet  [1383 1234] [0.52846771 0.47153229]
# Round 288 two large crickets meet  [1383 1240] [0.52725886 0.47274114]
# Round 289 two large crickets meet  [1383 1246] [0.52605553 0.47394447]
# Round 290 a small meets a large    [1384 1254] [0.52463988 0.47536012]
# Round 291 two large crickets meet  [1384 1260] [0.52344932 0.47655068]
# Round 292 two small crickets meet  [1394 1260] [0.52524491 0.47475509]
# Round 293 two large crickets meet  [1394 1266] [0.52406015 0.47593985]
# Round 294 a small meets a large    [1395 1274] [0.52266767 0.47733233]
# Round 295 a small meets a large    [1396 1282] [0.52128454 0.47871546]
# Round 296 a small meets a large    [1397 1290] [0.51991068 0.48008932]
# Round 297 a small meets a large    [1398 1298] [0.51854599 0.48145401]
# Round 298 two large crickets meet  [1398 1304] [0.51739452 0.48260548]
# Round 299 a small meets a large    [1399 1312] [0.51604574 0.48395426]
# Round 300 two small crickets meet  [1409 1312] [0.51782433 0.48217567]
# Round 301 a small meets a large    [1410 1320] [0.51648352 0.48351648]
# Round 302 two small crickets meet  [1420 1320] [0.51824818 0.48175182]
# Round 303 a small meets a large    [1421 1328] [0.51691524 0.48308476]
# Round 304 a small meets a large    [1422 1336] [0.51559101 0.48440899]
# Round 305 two small crickets meet  [1432 1336] [0.51734104 0.48265896]
# Round 306 two large crickets meet  [1432 1342] [0.51622206 0.48377794]
# Round 307 a small meets a large    [1433 1350] [0.51491197 0.48508803]
# Round 308 two large crickets meet  [1433 1356] [0.51380423 0.48619577]
# Round 309 two large crickets meet  [1433 1362] [0.51270125 0.48729875]
# Round 310 two small crickets meet  [1443 1362] [0.5144385 0.4855615]
# Round 311 a small meets a large    [1444 1370] [0.51314854 0.48685146]
# Round 312 two small crickets meet  [1454 1370] [0.51487252 0.48512748]
# Round 313 a small meets a large    [1455 1378] [0.51358983 0.48641017]
# Round 314 a small meets a large    [1456 1386] [0.51231527 0.48768473]
# Round 315 two large crickets meet  [1456 1392] [0.51123596 0.48876404]
# Round 316 two small crickets meet  [1466 1392] [0.51294612 0.48705388]
# Round 317 two large crickets meet  [1466 1398] [0.51187151 0.48812849]
# Round 318 a small meets a large    [1467 1406] [0.51061608 0.48938392]
# Round 319 a small meets a large    [1468 1414] [0.50936849 0.49063151]
# Round 320 two large crickets meet  [1468 1420] [0.50831025 0.49168975]
# Round 321 two large crickets meet  [1468 1426] [0.50725639 0.49274361]
# Round 322 two small crickets meet  [1478 1426] [0.50895317 0.49104683]
# Round 323 two small crickets meet  [1488 1426] [0.5106383 0.4893617]
# Round 324 two small crickets meet  [1498 1426] [0.5123119 0.4876881]
# Round 325 two small crickets meet  [1508 1426] [0.5139741 0.4860259]
# Round 326 a small meets a large    [1509 1434] [0.5127421 0.4872579]
# Round 327 two small crickets meet  [1519 1434] [0.51439214 0.48560786]
# Round 328 two small crickets meet  [1529 1434] [0.51603105 0.48396895]
# Round 329 two small crickets meet  [1539 1434] [0.51765893 0.48234107]
# Round 330 a small meets a large    [1540 1442] [0.51643192 0.48356808]
# Round 331 two small crickets meet  [1550 1442] [0.51804813 0.48195187]
# Round 332 two small crickets meet  [1560 1442] [0.51965356 0.48034644]
# Round 333 a small meets a large    [1561 1450] [0.51843241 0.48156759]
# Round 334 a small meets a large    [1562 1458] [0.51721854 0.48278146]
# Round 335 two small crickets meet  [1572 1458] [0.51881188 0.48118812]
# Round 336 two large crickets meet  [1572 1464] [0.51778656 0.48221344]
# Round 337 a small meets a large    [1573 1472] [0.51658456 0.48341544]
# Round 338 a small meets a large    [1574 1480] [0.51538965 0.48461035]
# Round 339 a small meets a large    [1575 1488] [0.51420176 0.48579824]
# Round 340 two large crickets meet  [1575 1494] [0.51319648 0.48680352]
# Round 341 a small meets a large    [1576 1502] [0.51202079 0.48797921]
# Round 342 two small crickets meet  [1586 1502] [0.51360104 0.48639896]
# Round 343 a small meets a large    [1587 1510] [0.51243139 0.48756861]
# Round 344 two small crickets meet  [1597 1510] [0.51400064 0.48599936]
# Round 345 a small meets a large    [1598 1518] [0.51283697 0.48716303]
# Round 346 a small meets a large    [1599 1526] [0.51168 0.48832]
# Round 347 two large crickets meet  [1599 1532] [0.51069946 0.48930054]
# Round 348 a small meets a large    [1600 1540] [0.50955414 0.49044586]
# Round 349 a small meets a large    [1601 1548] [0.50841537 0.49158463]
# Round 350 a small meets a large    [1602 1556] [0.50728309 0.49271691]
# Round 351 a small meets a large    [1603 1564] [0.50615725 0.49384275]
# Round 352 a small meets a large    [1604 1572] [0.50503778 0.49496222]
# Round 353 two large crickets meet  [1604 1578] [0.50408548 0.49591452]
# Round 354 two small crickets meet  [1614 1578] [0.5056391 0.4943609]
# Round 355 a small meets a large    [1615 1586] [0.50452983 0.49547017]
# Round 356 two small crickets meet  [1625 1586] [0.50607287 0.49392713]
# Round 357 a small meets a large    [1626 1594] [0.50496894 0.49503106]
# Round 358 a small meets a large    [1627 1602] [0.50387117 0.49612883]
# Round 359 two small crickets meet  [1637 1602] [0.5054029 0.4945971]
# Round 360 a small meets a large    [1638 1610] [0.50431034 0.49568966]
# Round 361 two large crickets meet  [1638 1616] [0.50338045 0.49661955]
# Round 362 a small meets a large    [1639 1624] [0.5022985 0.4977015]
# Round 363 a small meets a large    [1640 1632] [0.50122249 0.49877751]
# Round 364 a small meets a large    [1641 1640] [0.50015239 0.49984761]
# Round 365 a small meets a large    [1642 1648] [0.49908815 0.50091185]
# Round 366 two small crickets meet  [1652 1648] [0.50060606 0.49939394]
# Round 367 a small meets a large    [1653 1656] [0.49954669 0.50045331]
# Round 368 two small crickets meet  [1663 1656] [0.50105453 0.49894547]
# Round 369 two large crickets meet  [1663 1662] [0.50015038 0.49984962]
# Round 370 a small meets a large    [1664 1670] [0.49910018 0.50089982]
# Round 371 two large crickets meet  [1664 1676] [0.49820359 0.50179641]
# Round 372 two large crickets meet  [1664 1682] [0.49731022 0.50268978]
# Round 373 two large crickets meet  [1664 1688] [0.49642005 0.50357995]
# Round 374 a small meets a large    [1665 1696] [0.49538828 0.50461172]
# Round 375 a small meets a large    [1666 1704] [0.49436202 0.50563798]
# Round 376 a small meets a large    [1667 1712] [0.49334123 0.50665877]
# Round 377 a small meets a large    [1668 1720] [0.49232586 0.50767414]
# Round 378 two large crickets meet  [1668 1726] [0.49145551 0.50854449]
# Round 379 two small crickets meet  [1678 1726] [0.49294947 0.50705053]
# Round 380 a small meets a large    [1679 1734] [0.49194257 0.50805743]
# Round 381 two large crickets meet  [1679 1740] [0.49107926 0.50892074]
# Round 382 a small meets a large    [1680 1748] [0.49008168 0.50991832]
# Round 383 two small crickets meet  [1690 1748] [0.49156486 0.50843514]
# Round 384 two large crickets meet  [1690 1754] [0.49070848 0.50929152]
# Round 385 two large crickets meet  [1690 1760] [0.48985507 0.51014493]
# Round 386 two large crickets meet  [1690 1766] [0.48900463 0.51099537]
# Round 387 two small crickets meet  [1700 1766] [0.49047894 0.50952106]
# Round 388 a small meets a large    [1701 1774] [0.4894964 0.5105036]
# Round 389 two small crickets meet  [1711 1774] [0.49096126 0.50903874]
# Round 390 a small meets a large    [1712 1782] [0.48998283 0.51001717]
# Round 391 a small meets a large    [1713 1790] [0.48900942 0.51099058]
# Round 392 a small meets a large    [1714 1798] [0.488041 0.511959]
# Round 393 a small meets a large    [1715 1806] [0.48707753 0.51292247]
# Round 394 two large crickets meet  [1715 1812] [0.48624894 0.51375106]
# Round 395 two large crickets meet  [1715 1818] [0.48542315 0.51457685]
# Round 396 two large crickets meet  [1715 1824] [0.48460017 0.51539983]
# Round 397 two large crickets meet  [1715 1830] [0.48377997 0.51622003]
# Round 398 two small crickets meet  [1725 1830] [0.48523207 0.51476793]
# Round 399 a small meets a large    [1726 1838] [0.48428732 0.51571268]
# Round 400 two small crickets meet  [1736 1838] [0.48573027 0.51426973]
# Round 401 a small meets a large    [1737 1846] [0.48478928 0.51521072]
# Round 402 two large crickets meet  [1737 1852] [0.48397882 0.51602118]
# Round 403 two small crickets meet  [1747 1852] [0.48541261 0.51458739]
# Round 404 two small crickets meet  [1757 1852] [0.48683846 0.51316154]
# Round 405 two small crickets meet  [1767 1852] [0.48825642 0.51174358]
# Round 406 two large crickets meet  [1767 1858] [0.48744828 0.51255172]
# Round 407 a small meets a large    [1768 1866] [0.48651624 0.51348376]
# Round 408 two small crickets meet  [1778 1866] [0.48792536 0.51207464]
# Round 409 two small crickets meet  [1788 1866] [0.48932677 0.51067323]
# Round 410 a small meets a large    [1789 1874] [0.48839749 0.51160251]
# Round 411 a small meets a large    [1790 1882] [0.48747277 0.51252723]
# Round 412 two small crickets meet  [1800 1882] [0.48886475 0.51113525]
# Round 413 a small meets a large    [1801 1890] [0.48794365 0.51205635]
# Round 414 two small crickets meet  [1811 1890] [0.48932721 0.51067279]
# Round 415 a small meets a large    [1812 1898] [0.4884097 0.5115903]
# Round 416 a small meets a large    [1813 1906] [0.48749664 0.51250336]
# Round 417 two large crickets meet  [1813 1912] [0.48671141 0.51328859]
# Round 418 a small meets a large    [1814 1920] [0.48580611 0.51419389]
# Round 419 two large crickets meet  [1814 1926] [0.48502674 0.51497326]
# Round 420 a small meets a large    [1815 1934] [0.4841291 0.5158709]
# Round 421 two large crickets meet  [1815 1940] [0.48335553 0.51664447]
# Round 422 two small crickets meet  [1825 1940] [0.48472776 0.51527224]
# Round 423 two large crickets meet  [1825 1946] [0.48395651 0.51604349]
# Round 424 a small meets a large    [1826 1954] [0.48306878 0.51693122]
# Round 425 two large crickets meet  [1826 1960] [0.48230322 0.51769678]
# Round 426 a small meets a large    [1827 1968] [0.48142292 0.51857708]
# Round 427 two large crickets meet  [1827 1974] [0.48066298 0.51933702]
# Round 428 two small crickets meet  [1837 1974] [0.48202572 0.51797428]
# Round 429 two small crickets meet  [1847 1974] [0.48338131 0.51661869]
# Round 430 two small crickets meet  [1857 1974] [0.48472984 0.51527016]
# Round 431 a small meets a large    [1858 1982] [0.48385417 0.51614583]
# Round 432 two large crickets meet  [1858 1988] [0.48309932 0.51690068]
# Round 433 two small crickets meet  [1868 1988] [0.48443983 0.51556017]
# Round 434 two small crickets meet  [1878 1988] [0.48577341 0.51422659]
# Round 435 a small meets a large    [1879 1996] [0.48490323 0.51509677]
# Round 436 a small meets a large    [1880 2004] [0.48403708 0.51596292]
# Round 437 a small meets a large    [1881 2012] [0.48317493 0.51682507]
# Round 438 a small meets a large    [1882 2020] [0.48231676 0.51768324]
# Round 439 two small crickets meet  [1892 2020] [0.48364008 0.51635992]
# Round 440 two small crickets meet  [1902 2020] [0.48495665 0.51504335]
# Round 441 two large crickets meet  [1902 2026] [0.48421589 0.51578411]
# Round 442 two large crickets meet  [1902 2032] [0.48347738 0.51652262]
# Round 443 a small meets a large    [1903 2040] [0.48262744 0.51737256]
# Round 444 a small meets a large    [1904 2048] [0.48178138 0.51821862]
# Round 445 a small meets a large    [1905 2056] [0.48093916 0.51906084]
# Round 446 two large crickets meet  [1905 2062] [0.48021175 0.51978825]
# Round 447 two small crickets meet  [1915 2062] [0.48151873 0.51848127]
# Round 448 a small meets a large    [1916 2070] [0.48068239 0.51931761]
# Round 449 a small meets a large    [1917 2078] [0.47984981 0.52015019]
# Round 450 two small crickets meet  [1927 2078] [0.48114856 0.51885144]
# Round 451 a small meets a large    [1928 2086] [0.48031888 0.51968112]
# Round 452 a small meets a large    [1929 2094] [0.47949292 0.52050708]
# Round 453 two small crickets meet  [1939 2094] [0.48078354 0.51921646]
# Round 454 two large crickets meet  [1939 2100] [0.48006932 0.51993068]
# Round 455 two small crickets meet  [1949 2100] [0.48135342 0.51864658]
# Round 456 two small crickets meet  [1959 2100] [0.48263119 0.51736881]
# Round 457 two large crickets meet  [1959 2106] [0.48191882 0.51808118]
# Round 458 two small crickets meet  [1969 2106] [0.48319018 0.51680982]
# Round 459 a small meets a large    [1970 2114] [0.48237023 0.51762977]
# Round 460 a small meets a large    [1971 2122] [0.48155387 0.51844613]
# Round 461 a small meets a large    [1972 2130] [0.4807411 0.5192589]
# Round 462 two small crickets meet  [1982 2130] [0.48200389 0.51799611]
# Round 463 a small meets a large    [1983 2138] [0.48119388 0.51880612]
# Round 464 a small meets a large    [1984 2146] [0.48038741 0.51961259]
# Round 465 a small meets a large    [1985 2154] [0.47958444 0.52041556]
# Round 466 two large crickets meet  [1985 2160] [0.47889023 0.52110977]
# Round 467 a small meets a large    [1986 2168] [0.4780934 0.5219066]
# Round 468 two small crickets meet  [1996 2168] [0.47934678 0.52065322]
# Round 469 a small meets a large    [1997 2176] [0.4785526 0.5214474]
# Round 470 two small crickets meet  [2007 2176] [0.47979919 0.52020081]
# Round 471 two large crickets meet  [2007 2182] [0.47911196 0.52088804]
# Round 472 a small meets a large    [2008 2190] [0.47832301 0.52167699]
# Round 473 a small meets a large    [2009 2198] [0.47753744 0.52246256]
# Round 474 two small crickets meet  [2019 2198] [0.47877638 0.52122362]
# Round 475 two large crickets meet  [2019 2204] [0.47809614 0.52190386]
# Round 476 two large crickets meet  [2019 2210] [0.47741783 0.52258217]
# Round 477 two large crickets meet  [2019 2216] [0.47674144 0.52325856]
# Round 478 a small meets a large    [2020 2224] [0.47596607 0.52403393]
# Round 479 two small crickets meet  [2030 2224] [0.47719793 0.52280207]
# Round 480 two large crickets meet  [2030 2230] [0.47652582 0.52347418]
# Round 481 two small crickets meet  [2040 2230] [0.47775176 0.52224824]
# Round 482 a small meets a large    [2041 2238] [0.4769806 0.5230194]
# Round 483 two small crickets meet  [2051 2238] [0.47820005 0.52179995]
# Round 484 two large crickets meet  [2051 2244] [0.47753201 0.52246799]
# Round 485 two small crickets meet  [2061 2244] [0.47874564 0.52125436]
# Round 486 a small meets a large    [2062 2252] [0.47797867 0.52202133]
# Round 487 a small meets a large    [2063 2260] [0.4772149 0.5227851]
# Round 488 a small meets a large    [2064 2268] [0.47645429 0.52354571]
# Round 489 two large crickets meet  [2064 2274] [0.4757953 0.5242047]
# Round 490 a small meets a large    [2065 2282] [0.47504026 0.52495974]
# Round 491 a small meets a large    [2066 2290] [0.47428834 0.52571166]
# Round 492 two small crickets meet  [2076 2290] [0.47549244 0.52450756]
# Round 493 a small meets a large    [2077 2298] [0.47474286 0.52525714]
# Round 494 two small crickets meet  [2087 2298] [0.47594071 0.52405929]
# Round 495 a small meets a large    [2088 2306] [0.47519345 0.52480655]
# Round 496 two large crickets meet  [2088 2312] [0.47454545 0.52545455]
# Round 497 a small meets a large    [2089 2320] [0.47380358 0.52619642]
# Round 498 two large crickets meet  [2089 2326] [0.47315968 0.52684032]
# Round 499 a small meets a large    [2090 2334] [0.47242315 0.52757685]
# Round 500 a small meets a large    [2091 2342] [0.4716896 0.5283104]
# Round 501 a small meets a large    [2092 2350] [0.47095903 0.52904097]
# Round 502 a small meets a large    [2093 2358] [0.47023141 0.52976859]
# Round 503 two large crickets meet  [2093 2364] [0.46959838 0.53040162]
# Round 504 a small meets a large    [2094 2372] [0.46887595 0.53112405]
# Round 505 a small meets a large    [2095 2380] [0.46815642 0.53184358]
# Round 506 a small meets a large    [2096 2388] [0.46743979 0.53256021]
# Round 507 a small meets a large    [2097 2396] [0.46672602 0.53327398]
# Round 508 a small meets a large    [2098 2404] [0.4660151 0.5339849]
# Round 509 two small crickets meet  [2108 2404] [0.46719858 0.53280142]
# Round 510 two large crickets meet  [2108 2410] [0.46657813 0.53342187]
# Round 511 two large crickets meet  [2108 2416] [0.46595933 0.53404067]
# Round 512 two large crickets meet  [2108 2422] [0.46534216 0.53465784]
# Round 513 a small meets a large    [2109 2430] [0.46463979 0.53536021]
# Round 514 two large crickets meet  [2109 2436] [0.4640264 0.5359736]
# Round 515 two large crickets meet  [2109 2442] [0.46341463 0.53658537]
# Round 516 two large crickets meet  [2109 2448] [0.46280448 0.53719552]
# Round 517 two large crickets meet  [2109 2454] [0.46219592 0.53780408]
# Round 518 two large crickets meet  [2109 2460] [0.46158897 0.53841103]
# Round 519 a small meets a large    [2110 2468] [0.46089996 0.53910004]
# Round 520 a small meets a large    [2111 2476] [0.46021365 0.53978635]
# Round 521 two small crickets meet  [2121 2476] [0.46138786 0.53861214]
# Round 522 two small crickets meet  [2131 2476] [0.46255698 0.53744302]
# Round 523 two large crickets meet  [2131 2482] [0.46195534 0.53804466]
# Round 524 a small meets a large    [2132 2490] [0.46127218 0.53872782]
# Round 525 a small meets a large    [2133 2498] [0.46059166 0.53940834]
# Round 526 two small crickets meet  [2143 2498] [0.46175393 0.53824607]
# Round 527 a small meets a large    [2144 2506] [0.46107527 0.53892473]
# Round 528 two large crickets meet  [2144 2512] [0.4604811 0.5395189]
# Round 529 two small crickets meet  [2154 2512] [0.46163738 0.53836262]
# Round 530 a small meets a large    [2155 2520] [0.46096257 0.53903743]
# Round 531 two large crickets meet  [2155 2526] [0.46037172 0.53962828]
# Round 532 a small meets a large    [2156 2534] [0.45970149 0.54029851]
# Round 533 a small meets a large    [2157 2542] [0.45903384 0.54096616]
# Round 534 a small meets a large    [2158 2550] [0.45836873 0.54163127]
# Round 535 a small meets a large    [2159 2558] [0.45770617 0.54229383]
# Round 536 a small meets a large    [2160 2566] [0.45704613 0.54295387]
# Round 537 two large crickets meet  [2160 2572] [0.45646661 0.54353339]
# Round 538 a small meets a large    [2161 2580] [0.45581101 0.54418899]
# Round 539 two large crickets meet  [2161 2586] [0.45523489 0.54476511]
# Round 540 two small crickets meet  [2171 2586] [0.45638007 0.54361993]
# Round 541 two large crickets meet  [2171 2592] [0.45580516 0.54419484]
# Round 542 a small meets a large    [2172 2600] [0.45515507 0.54484493]
# Round 543 a small meets a large    [2173 2608] [0.45450743 0.54549257]
# Round 544 a small meets a large    [2174 2616] [0.45386221 0.54613779]
# Round 545 a small meets a large    [2175 2624] [0.45321942 0.54678058]
# Round 546 two small crickets meet  [2185 2624] [0.45435642 0.54564358]
# Round 547 two large crickets meet  [2185 2630] [0.45379024 0.54620976]
# Round 548 two small crickets meet  [2195 2630] [0.45492228 0.54507772]
# Round 549 two large crickets meet  [2195 2636] [0.45435728 0.54564272]
# Round 550 two large crickets meet  [2195 2642] [0.45379367 0.54620633]
# Round 551 two small crickets meet  [2205 2642] [0.45492057 0.54507943]
# Round 552 a small meets a large    [2206 2650] [0.45428336 0.54571664]
# Round 553 two small crickets meet  [2216 2650] [0.45540485 0.54459515]
# Round 554 a small meets a large    [2217 2658] [0.45476923 0.54523077]
# Round 555 two large crickets meet  [2217 2664] [0.4542102 0.5457898]
# Round 556 two large crickets meet  [2217 2670] [0.45365255 0.54634745]
# Round 557 a small meets a large    [2218 2678] [0.45302288 0.54697712]
# Round 558 a small meets a large    [2219 2686] [0.45239551 0.54760449]
# Round 559 a small meets a large    [2220 2694] [0.45177045 0.54822955]
# Round 560 a small meets a large    [2221 2702] [0.45114767 0.54885233]
# Round 561 two large crickets meet  [2221 2708] [0.4505985 0.5494015]
# Round 562 a small meets a large    [2222 2716] [0.44997975 0.55002025]
# Round 563 a small meets a large    [2223 2724] [0.44936325 0.55063675]
# Round 564 two large crickets meet  [2223 2730] [0.4488189 0.5511811]
# Round 565 a small meets a large    [2224 2738] [0.44820637 0.55179363]
# Round 566 a small meets a large    [2225 2746] [0.44759606 0.55240394]
# Round 567 two large crickets meet  [2225 2752] [0.44705646 0.55294354]
# Round 568 a small meets a large    [2226 2760] [0.44645006 0.55354994]
# Round 569 two small crickets meet  [2236 2760] [0.44755805 0.55244195]
# Round 570 two large crickets meet  [2236 2766] [0.44702119 0.55297881]
# Round 571 a small meets a large    [2237 2774] [0.44641788 0.55358212]
# Round 572 two large crickets meet  [2237 2780] [0.44588399 0.55411601]
# Round 573 two small crickets meet  [2247 2780] [0.44698627 0.55301373]
# Round 574 a small meets a large    [2248 2788] [0.44638602 0.55361398]
# Round 575 two small crickets meet  [2258 2788] [0.44748315 0.55251685]
# Round 576 two large crickets meet  [2258 2794] [0.4469517 0.5530483]
# Round 577 a small meets a large    [2259 2802] [0.44635448 0.55364552]
# Round 578 a small meets a large    [2260 2810] [0.44575937 0.55424063]
# Round 579 two small crickets meet  [2270 2810] [0.44685039 0.55314961]
# Round 580 two small crickets meet  [2280 2810] [0.44793713 0.55206287]
# Round 581 a small meets a large    [2281 2818] [0.44734262 0.55265738]
# Round 582 a small meets a large    [2282 2826] [0.4467502 0.5532498]
# Round 583 a small meets a large    [2283 2834] [0.44615986 0.55384014]
# Round 584 two large crickets meet  [2283 2840] [0.44563732 0.55436268]
# Round 585 a small meets a large    [2284 2848] [0.44505066 0.55494934]
# Round 586 two small crickets meet  [2294 2848] [0.44612991 0.55387009]
# Round 587 a small meets a large    [2295 2856] [0.44554455 0.55445545]
# Round 588 two small crickets meet  [2305 2856] [0.44661887 0.55338113]
# Round 589 two large crickets meet  [2305 2862] [0.44610025 0.55389975]
# Round 590 a small meets a large    [2306 2870] [0.44551777 0.55448223]
# Round 591 two large crickets meet  [2306 2876] [0.44500193 0.55499807]
# Round 592 a small meets a large    [2307 2884] [0.44442304 0.55557696]
# Round 593 a small meets a large    [2308 2892] [0.44384615 0.55615385]
# Round 594 a small meets a large    [2309 2900] [0.44327126 0.55672874]
# Round 595 two large crickets meet  [2309 2906] [0.44276127 0.55723873]
# Round 596 two small crickets meet  [2319 2906] [0.44382775 0.55617225]
# Round 597 two small crickets meet  [2329 2906] [0.44489016 0.55510984]
# Round 598 two large crickets meet  [2329 2912] [0.44438084 0.55561916]
# Round 599 a small meets a large    [2330 2920] [0.44380952 0.55619048]
# Round 600 two large crickets meet  [2330 2926] [0.44330289 0.55669711]
# Round 601 two large crickets meet  [2330 2932] [0.44279742 0.55720258]
# Round 602 two small crickets meet  [2340 2932] [0.44385432 0.55614568]
# Round 603 two large crickets meet  [2340 2938] [0.44334975 0.55665025]
# Round 604 a small meets a large    [2341 2946] [0.44278419 0.55721581]
# Round 605 two large crickets meet  [2341 2952] [0.44228226 0.55771774]
# Round 606 a small meets a large    [2342 2960] [0.44172011 0.55827989]
# Round 607 a small meets a large    [2343 2968] [0.44115986 0.55884014]
# Round 608 a small meets a large    [2344 2976] [0.4406015 0.5593985]
# Round 609 a small meets a large    [2345 2984] [0.44004504 0.55995496]
# Round 610 two small crickets meet  [2355 2984] [0.44109384 0.55890616]
# Round 611 a small meets a large    [2356 2992] [0.44053852 0.55946148]
# Round 612 a small meets a large    [2357 3000] [0.43998507 0.56001493]
# Round 613 two small crickets meet  [2367 3000] [0.44102851 0.55897149]
# Round 614 a small meets a large    [2368 3008] [0.44047619 0.55952381]
# Round 615 a small meets a large    [2369 3016] [0.43992572 0.56007428]
# Round 616 a small meets a large    [2370 3024] [0.43937709 0.56062291]
# Round 617 a small meets a large    [2371 3032] [0.43883028 0.56116972]
# Round 618 two small crickets meet  [2381 3032] [0.43986699 0.56013301]
# Round 619 a small meets a large    [2382 3040] [0.43932128 0.56067872]
# Round 620 a small meets a large    [2383 3048] [0.43877739 0.56122261]
# Round 621 two large crickets meet  [2383 3054] [0.43829318 0.56170682]
# Round 622 a small meets a large    [2384 3062] [0.43775248 0.56224752]
# Round 623 two large crickets meet  [2384 3068] [0.43727073 0.56272927]
# Round 624 two large crickets meet  [2384 3074] [0.43679003 0.56320997]
# Round 625 two large crickets meet  [2384 3080] [0.4363104 0.5636896]
# Round 626 two small crickets meet  [2394 3080] [0.43734015 0.56265985]
# Round 627 two small crickets meet  [2404 3080] [0.43836616 0.56163384]
# Round 628 two small crickets meet  [2414 3080] [0.43938842 0.56061158]
# Round 629 a small meets a large    [2415 3088] [0.43885154 0.56114846]
# Round 630 a small meets a large    [2416 3096] [0.4383164 0.5616836]
# Round 631 two large crickets meet  [2416 3102] [0.4378398 0.5621602]
# Round 632 a small meets a large    [2417 3110] [0.43730776 0.56269224]
# Round 633 two large crickets meet  [2417 3116] [0.43683354 0.56316646]
# Round 634 a small meets a large    [2418 3124] [0.43630458 0.56369542]
# Round 635 a small meets a large    [2419 3132] [0.43577734 0.56422266]
# Round 636 two large crickets meet  [2419 3138] [0.43530682 0.56469318]
# Round 637 two large crickets meet  [2419 3144] [0.43483732 0.56516268]
# Round 638 a small meets a large    [2420 3152] [0.43431443 0.56568557]
# Round 639 a small meets a large    [2421 3160] [0.43379323 0.56620677]
# Round 640 two small crickets meet  [2431 3160] [0.43480594 0.56519406]
# Round 641 two small crickets meet  [2441 3160] [0.43581503 0.56418497]
# Round 642 two small crickets meet  [2451 3160] [0.43682053 0.56317947]
# Round 643 two large crickets meet  [2451 3166] [0.43635393 0.56364607]
# Round 644 a small meets a large    [2452 3174] [0.43583363 0.56416637]
# Round 645 two large crickets meet  [2452 3180] [0.43536932 0.56463068]
# Round 646 a small meets a large    [2453 3188] [0.43485198 0.56514802]
# Round 647 two large crickets meet  [2453 3194] [0.43438994 0.56561006]
# Round 648 two small crickets meet  [2463 3194] [0.43538978 0.56461022]
# Round 649 two large crickets meet  [2463 3200] [0.43492848 0.56507152]
# Round 650 a small meets a large    [2464 3208] [0.43441467 0.56558533]
# Round 651 two large crickets meet  [2464 3214] [0.43395562 0.56604438]
# Round 652 a small meets a large    [2465 3222] [0.4334447 0.5665553]
# Round 653 two large crickets meet  [2465 3228] [0.43298788 0.56701212]
# Round 654 two small crickets meet  [2475 3228] [0.43398211 0.56601789]
# Round 655 two large crickets meet  [2475 3234] [0.43352601 0.56647399]
# Round 656 two small crickets meet  [2485 3234] [0.43451652 0.56548348]
# Round 657 a small meets a large    [2486 3242] [0.43400838 0.56599162]
# Round 658 a small meets a large    [2487 3250] [0.43350183 0.56649817]
# Round 659 two small crickets meet  [2497 3250] [0.43448756 0.56551244]
# Round 660 two large crickets meet  [2497 3256] [0.43403442 0.56596558]
# Round 661 two large crickets meet  [2497 3262] [0.43358222 0.56641778]
# Round 662 two small crickets meet  [2507 3262] [0.43456405 0.56543595]
# Round 663 two large crickets meet  [2507 3268] [0.43411255 0.56588745]
# Round 664 a small meets a large    [2508 3276] [0.43360996 0.56639004]
# Round 665 a small meets a large    [2509 3284] [0.43310892 0.56689108]
# Round 666 a small meets a large    [2510 3292] [0.43260945 0.56739055]
# Round 667 a small meets a large    [2511 3300] [0.43211151 0.56788849]
# Round 668 two large crickets meet  [2511 3306] [0.43166581 0.56833419]
# Round 669 two large crickets meet  [2511 3312] [0.43122102 0.56877898]
# Round 670 a small meets a large    [2512 3320] [0.43072702 0.56927298]
# Round 671 two small crickets meet  [2522 3320] [0.43170147 0.56829853]
# Round 672 two small crickets meet  [2532 3320] [0.43267259 0.56732741]
# Round 673 two large crickets meet  [2532 3326] [0.43222943 0.56777057]
# Round 674 two large crickets meet  [2532 3332] [0.43178718 0.56821282]
# Round 675 two large crickets meet  [2532 3338] [0.43134583 0.56865417]
# Round 676 two small crickets meet  [2542 3338] [0.43231293 0.56768707]
# Round 677 two small crickets meet  [2552 3338] [0.43327674 0.56672326]
# Round 678 two large crickets meet  [2552 3344] [0.43283582 0.56716418]
# Round 679 a small meets a large    [2553 3352] [0.43234547 0.56765453]
# Round 680 two large crickets meet  [2553 3358] [0.43190661 0.56809339]
# Round 681 a small meets a large    [2554 3366] [0.43141892 0.56858108]
# Round 682 a small meets a large    [2555 3374] [0.4309327 0.5690673]
# Round 683 two large crickets meet  [2555 3380] [0.43049705 0.56950295]
# ...
# Round 775 two small crickets meet  [2749 3930] [0.41158856 0.58841144]
# Round 776 two large crickets meet  [2749 3936] [0.41121915 0.58878085]
# Round 777 a small meets a large    [2750 3944] [0.41081566 0.58918434]
# Round 778 a small meets a large    [2751 3952] [0.41041325 0.58958675]
# Round 779 two large crickets meet  [2751 3958] [0.41004621 0.58995379]
# Round 780 two large crickets meet  [2751 3964] [0.40967982 0.59032018]
# Round 781 two small crickets meet  [2761 3964] [0.41055762 0.58944238]
# Round 782 two small crickets meet  [2771 3964] [0.41143281 0.58856719]
# Round 783 two small crickets meet  [2781 3964] [0.41230541 0.58769459]
# Round 784 a small meets a large    [2782 3972] [0.41190406 0.58809594]
# Round 785 two large crickets meet  [2782 3978] [0.41153846 0.58846154]
# Round 786 a small meets a large    [2783 3986] [0.41113902 0.58886098]
# Round 787 a small meets a large    [2784 3994] [0.41074063 0.58925937]
# Round 788 a small meets a large    [2785 4002] [0.4103433 0.5896567]
# Round 789 two small crickets meet  [2795 4002] [0.41121083 0.58878917]
# Round 790 two small crickets meet  [2805 4002] [0.4120758 0.5879242]
# Round 791 two small crickets meet  [2815 4002] [0.41293824 0.58706176]
# Round 792 a small meets a large    [2816 4010] [0.41254029 0.58745971]
# Round 793 two large crickets meet  [2816 4016] [0.41217799 0.58782201]
# Round 794 two large crickets meet  [2816 4022] [0.41181632 0.58818368]
# Round 795 two large crickets meet  [2816 4028] [0.41145529 0.58854471]
# Round 796 a small meets a large    [2817 4036] [0.41106085 0.58893915]
# Round 797 a small meets a large    [2818 4044] [0.41066744 0.58933256]
# Round 798 two large crickets meet  [2818 4050] [0.41030868 0.58969132]
# Round 799 a small meets a large    [2819 4058] [0.40991712 0.59008288]
# Round 800 a small meets a large    [2820 4066] [0.40952658 0.59047342]
# Round 801 two small crickets meet  [2830 4066] [0.41038283 0.58961717]
# Round 802 two large crickets meet  [2830 4072] [0.41002608 0.58997392]
# Round 803 two large crickets meet  [2830 4078] [0.40966995 0.59033005]
# Round 804 two large crickets meet  [2830 4084] [0.40931443 0.59068557]
# Round 805 a small meets a large    [2831 4092] [0.40892677 0.59107323]
# Round 806 a small meets a large    [2832 4100] [0.4085401 0.5914599]
# Round 807 two small crickets meet  [2842 4100] [0.40939211 0.59060789]
# Round 808 a small meets a large    [2843 4108] [0.4090059 0.5909941]
# Round 809 a small meets a large    [2844 4116] [0.40862069 0.59137931]
# Round 810 a small meets a large    [2845 4124] [0.40823648 0.59176352]
# Round 811 two small crickets meet  [2855 4124] [0.4090844 0.5909156]
# Round 812 two large crickets meet  [2855 4130] [0.408733 0.591267]
# Round 813 a small meets a large    [2856 4138] [0.40835001 0.59164999]
# Round 814 a small meets a large    [2857 4146] [0.40796801 0.59203199]
# Round 815 a small meets a large    [2858 4154] [0.40758699 0.59241301]
# Round 816 two large crickets meet  [2858 4160] [0.40723853 0.59276147]
# Round 817 a small meets a large    [2859 4168] [0.40685926 0.59314074]
# Round 818 a small meets a large    [2860 4176] [0.40648096 0.59351904]
# Round 819 a small meets a large    [2861 4184] [0.40610362 0.59389638]
# Round 820 two small crickets meet  [2871 4184] [0.40694543 0.59305457]
# Round 821 a small meets a large    [2872 4192] [0.40656852 0.59343148]
# Round 822 a small meets a large    [2873 4200] [0.40619256 0.59380744]
# Round 823 two large crickets meet  [2873 4206] [0.40584828 0.59415172]
# Round 824 two small crickets meet  [2883 4206] [0.40668642 0.59331358]
# Round 825 a small meets a large    [2884 4214] [0.40631164 0.59368836]
# Round 826 a small meets a large    [2885 4222] [0.40593781 0.59406219]
# Round 827 two small crickets meet  [2895 4222] [0.40677252 0.59322748]
# Round 828 a small meets a large    [2896 4230] [0.4063991 0.5936009]
# Round 829 two large crickets meet  [2896 4236] [0.40605721 0.59394279]
# Round 830 two large crickets meet  [2896 4242] [0.40571589 0.59428411]
# Round 831 two large crickets meet  [2896 4248] [0.40537514 0.59462486]
# Round 832 a small meets a large    [2897 4256] [0.40500489 0.59499511]
# Round 833 two large crickets meet  [2897 4262] [0.40466546 0.59533454]
# Round 834 a small meets a large    [2898 4270] [0.40429688 0.59570312]
# Round 835 a small meets a large    [2899 4278] [0.40392922 0.59607078]
# Round 836 two large crickets meet  [2899 4284] [0.40359181 0.59640819]
# Round 837 two large crickets meet  [2899 4290] [0.40325497 0.59674503]
# Round 838 two small crickets meet  [2909 4290] [0.4040839 0.5959161]
# Round 839 a small meets a large    [2910 4298] [0.40371809 0.59628191]
# Round 840 two large crickets meet  [2910 4304] [0.40338231 0.59661769]
# Round 841 a small meets a large    [2911 4312] [0.40301814 0.59698186]
# Round 842 a small meets a large    [2912 4320] [0.40265487 0.59734513]
# Round 843 two large crickets meet  [2912 4326] [0.40232108 0.59767892]
# Round 844 two large crickets meet  [2912 4332] [0.40198785 0.59801215]
# Round 845 a small meets a large    [2913 4340] [0.40162691 0.59837309]
# Round 846 two large crickets meet  [2913 4346] [0.40129494 0.59870506]
# Round 847 two large crickets meet  [2913 4352] [0.40096352 0.59903648]
# Round 848 two large crickets meet  [2913 4358] [0.40063265 0.59936735]
# Round 849 a small meets a large    [2914 4366] [0.40027473 0.59972527]
# Round 850 two large crickets meet  [2914 4372] [0.3999451 0.6000549]
# Round 851 two large crickets meet  [2914 4378] [0.39961602 0.60038398]
# Round 852 a small meets a large    [2915 4386] [0.39926038 0.60073962]
# Round 853 two small crickets meet  [2925 4386] [0.40008207 0.59991793]
# Round 854 two large crickets meet  [2925 4392] [0.399754 0.600246]
# Round 855 a small meets a large    [2926 4400] [0.3993994 0.6006006]
# Round 856 a small meets a large    [2927 4408] [0.39904567 0.60095433]
# Round 857 two large crickets meet  [2927 4414] [0.39871952 0.60128048]
# Round 858 two large crickets meet  [2927 4420] [0.3983939 0.6016061]
# Round 859 two large crickets meet  [2927 4426] [0.39806882 0.60193118]
# Round 860 a small meets a large    [2928 4434] [0.39771801 0.60228199]
# Round 861 two large crickets meet  [2928 4440] [0.39739414 0.60260586]
# Round 862 a small meets a large    [2929 4448] [0.39704487 0.60295513]
# Round 863 two small crickets meet  [2939 4448] [0.39786111 0.60213889]
# Round 864 two large crickets meet  [2939 4454] [0.39753821 0.60246179]
# Round 865 two small crickets meet  [2949 4454] [0.39835202 0.60164798]
# Round 866 a small meets a large    [2950 4462] [0.39800324 0.60199676]
# Round 867 two large crickets meet  [2950 4468] [0.39768132 0.60231868]
# Round 868 a small meets a large    [2951 4476] [0.39733405 0.60266595]
# Round 869 two large crickets meet  [2951 4482] [0.39701332 0.60298668]
# Round 870 two small crickets meet  [2961 4482] [0.39782346 0.60217654]
# Round 871 two small crickets meet  [2971 4482] [0.39863142 0.60136858]
# Round 872 two large crickets meet  [2971 4488] [0.39831077 0.60168923]
# Round 873 a small meets a large    [2972 4496] [0.39796465 0.60203535]
# Round 874 two large crickets meet  [2972 4502] [0.39764517 0.60235483]
# Round 875 two small crickets meet  [2982 4502] [0.39845003 0.60154997]
# Round 876 two large crickets meet  [2982 4508] [0.39813084 0.60186916]
# Round 877 two small crickets meet  [2992 4508] [0.39893333 0.60106667]
# Round 878 a small meets a large    [2993 4516] [0.39858836 0.60141164]
# Round 879 two large crickets meet  [2993 4522] [0.39827013 0.60172987]
# Round 880 two large crickets meet  [2993 4528] [0.3979524 0.6020476]
# Round 881 two large crickets meet  [2993 4534] [0.39763518 0.60236482]
# Round 882 a small meets a large    [2994 4542] [0.39729299 0.60270701]
# Round 883 two large crickets meet  [2994 4548] [0.39697693 0.60302307]
# Round 884 two large crickets meet  [2994 4554] [0.39666137 0.60333863]
# Round 885 two large crickets meet  [2994 4560] [0.39634631 0.60365369]
# Round 886 a small meets a large    [2995 4568] [0.39600688 0.60399312]
# Round 887 a small meets a large    [2996 4576] [0.39566825 0.60433175]
# Round 888 two large crickets meet  [2996 4582] [0.39535497 0.60464503]
# Round 889 two large crickets meet  [2996 4588] [0.39504219 0.60495781]
# Round 890 two large crickets meet  [2996 4594] [0.39472991 0.60527009]
# Round 891 a small meets a large    [2997 4602] [0.394394 0.605606]
# Round 892 two large crickets meet  [2997 4608] [0.39408284 0.60591716]
# Round 893 a small meets a large    [2998 4616] [0.39374836 0.60625164]
# Round 894 two large crickets meet  [2998 4622] [0.39343832 0.60656168]
# Round 895 a small meets a large    [2999 4630] [0.39310526 0.60689474]
# Round 896 a small meets a large    [3000 4638] [0.39277298 0.60722702]
# Round 897 two large crickets meet  [3000 4644] [0.39246468 0.60753532]
# Round 898 two large crickets meet  [3000 4650] [0.39215686 0.60784314]
# Round 899 two large crickets meet  [3000 4656] [0.39184953 0.60815047]
# Round 900 a small meets a large    [3001 4664] [0.3915199 0.6084801]
# Round 901 a small meets a large    [3002 4672] [0.39119103 0.60880897]
# Round 902 a small meets a large    [3003 4680] [0.39086294 0.60913706]
# Round 903 a small meets a large    [3004 4688] [0.39053562 0.60946438]
# Round 904 two large crickets meet  [3004 4694] [0.39023123 0.60976877]
# Round 905 a small meets a large    [3005 4702] [0.38990528 0.61009472]
# Round 906 two small crickets meet  [3015 4702] [0.39069587 0.60930413]
# Round 907 a small meets a large    [3016 4710] [0.39037018 0.60962982]
# Round 908 two large crickets meet  [3016 4716] [0.39006725 0.60993275]
# Round 909 two large crickets meet  [3016 4722] [0.3897648 0.6102352]
# Round 910 two large crickets meet  [3016 4728] [0.38946281 0.61053719]
# Round 911 a small meets a large    [3017 4736] [0.38913969 0.61086031]
# Round 912 two large crickets meet  [3017 4742] [0.38883877 0.61116123]
# Round 913 a small meets a large    [3018 4750] [0.38851699 0.61148301]
# Round 914 two large crickets meet  [3018 4756] [0.38821713 0.61178287]
# Round 915 a small meets a large    [3019 4764] [0.3878967 0.6121033]
# Round 916 a small meets a large    [3020 4772] [0.387577 0.612423]
# Round 917 two small crickets meet  [3030 4772] [0.38836196 0.61163804]
# Round 918 a small meets a large    [3031 4780] [0.3880425 0.6119575]
# Round 919 a small meets a large    [3032 4788] [0.38772379 0.61227621]
# Round 920 a small meets a large    [3033 4796] [0.3874058 0.6125942]
# Round 921 two large crickets meet  [3033 4802] [0.38710913 0.61289087]
# Round 922 a small meets a large    [3034 4810] [0.38679245 0.61320755]
# Round 923 two large crickets meet  [3034 4816] [0.38649682 0.61350318]
# Round 924 a small meets a large    [3035 4824] [0.38618145 0.61381855]
# Round 925 two large crickets meet  [3035 4830] [0.38588684 0.61411316]
# Round 926 a small meets a large    [3036 4838] [0.38557277 0.61442723]
# Round 927 a small meets a large    [3037 4846] [0.38525942 0.61474058]
# Round 928 a small meets a large    [3038 4854] [0.38494678 0.61505322]
# Round 929 two large crickets meet  [3038 4860] [0.38465434 0.61534566]
# Round 930 two large crickets meet  [3038 4866] [0.38436235 0.61563765]
# Round 931 two small crickets meet  [3048 4866] [0.38514026 0.61485974]
# Round 932 two large crickets meet  [3048 4872] [0.38484848 0.61515152]
# Round 933 a small meets a large    [3049 4880] [0.38453777 0.61546223]
# Round 934 a small meets a large    [3050 4888] [0.38422777 0.61577223]
# Round 935 a small meets a large    [3051 4896] [0.38391846 0.61608154]
# Round 936 a small meets a large    [3052 4904] [0.38360985 0.61639015]
# Round 937 a small meets a large    [3053 4912] [0.38330195 0.61669805]
# Round 938 a small meets a large    [3054 4920] [0.38299473 0.61700527]
# Round 939 two large crickets meet  [3054 4926] [0.38270677 0.61729323]
# Round 940 two large crickets meet  [3054 4932] [0.38241923 0.61758077]
# Round 941 a small meets a large    [3055 4940] [0.38211382 0.61788618]
# Round 942 two small crickets meet  [3065 4940] [0.3828857 0.6171143]
# Round 943 a small meets a large    [3066 4948] [0.38258048 0.61741952]
# Round 944 two large crickets meet  [3066 4954] [0.38229426 0.61770574]
# Round 945 two large crickets meet  [3066 4960] [0.38200847 0.61799153]
# Round 946 two large crickets meet  [3066 4966] [0.38172311 0.61827689]
# Round 947 a small meets a large    [3067 4974] [0.38142022 0.61857978]
# Round 948 a small meets a large    [3068 4982] [0.38111801 0.61888199]
# Round 949 two large crickets meet  [3068 4988] [0.38083416 0.61916584]
# Round 950 two small crickets meet  [3078 4988] [0.38160179 0.61839821]
# Round 951 two large crickets meet  [3078 4994] [0.38131814 0.61868186]
# Round 952 a small meets a large    [3079 5002] [0.3810172 0.6189828]
# Round 953 two small crickets meet  [3089 5002] [0.38178223 0.61821777]
# Round 954 a small meets a large    [3090 5010] [0.38148148 0.61851852]
# Round 955 two large crickets meet  [3090 5016] [0.38119911 0.61880089]
# Round 956 a small meets a large    [3091 5024] [0.38089957 0.61910043]
# Round 957 two large crickets meet  [3091 5030] [0.38061815 0.61938185]
# Round 958 two large crickets meet  [3091 5036] [0.38033715 0.61966285]
# Round 959 two large crickets meet  [3091 5042] [0.38005656 0.61994344]
# Round 960 a small meets a large    [3092 5050] [0.37975927 0.62024073]
# Round 961 two small crickets meet  [3102 5050] [0.38052012 0.61947988]
# Round 962 a small meets a large    [3103 5058] [0.38022301 0.61977699]
# Round 963 a small meets a large    [3104 5066] [0.37992656 0.62007344]
# Round 964 two small crickets meet  [3114 5066] [0.3806846 0.6193154]
# Round 965 two large crickets meet  [3114 5072] [0.38040557 0.61959443]
# Round 966 two small crickets meet  [3124 5072] [0.38116154 0.61883846]
# Round 967 two small crickets meet  [3134 5072] [0.38191567 0.61808433]
# Round 968 a small meets a large    [3135 5080] [0.38161899 0.61838101]
# Round 969 a small meets a large    [3136 5088] [0.38132296 0.61867704]
# Round 970 two large crickets meet  [3136 5094] [0.38104496 0.61895504]
# Round 971 a small meets a large    [3137 5102] [0.38075009 0.61924991]
# Round 972 two large crickets meet  [3137 5108] [0.38047301 0.61952699]
# Round 973 a small meets a large    [3138 5116] [0.38017931 0.61982069]
# Round 974 a small meets a large    [3139 5124] [0.37988624 0.62011376]
# Round 975 a small meets a large    [3140 5132] [0.37959381 0.62040619]
# Round 976 a small meets a large    [3141 5140] [0.37930202 0.62069798]
# Round 977 a small meets a large    [3142 5148] [0.37901086 0.62098914]
# Round 978 a small meets a large    [3143 5156] [0.37872033 0.62127967]
# Round 979 two large crickets meet  [3143 5162] [0.37844672 0.62155328]
# Round 980 a small meets a large    [3144 5170] [0.37815732 0.62184268]
# Round 981 a small meets a large    [3145 5178] [0.37786856 0.62213144]
# Round 982 a small meets a large    [3146 5186] [0.37758041 0.62241959]
# Round 983 a small meets a large    [3147 5194] [0.37729289 0.62270711]
# Round 984 a small meets a large    [3148 5202] [0.37700599 0.62299401]
# Round 985 two small crickets meet  [3158 5202] [0.3777512 0.6222488]
# Round 986 a small meets a large    [3159 5210] [0.37746445 0.62253555]
# Round 987 a small meets a large    [3160 5218] [0.37717832 0.62282168]
# Round 988 a small meets a large    [3161 5226] [0.37689281 0.62310719]
# Round 989 two small crickets meet  [3171 5226] [0.37763487 0.62236513]
# Round 990 two large crickets meet  [3171 5232] [0.37736523 0.62263477]
# Round 991 a small meets a large    [3172 5240] [0.37708036 0.62291964]
# Round 992 a small meets a large    [3173 5248] [0.3767961 0.6232039]
# Round 993 two large crickets meet  [3173 5254] [0.37652783 0.62347217]
# Round 994 a small meets a large    [3174 5262] [0.37624467 0.62375533]
# Round 995 two large crickets meet  [3174 5268] [0.37597726 0.62402274]
# Round 996 a small meets a large    [3175 5276] [0.37569518 0.62430482]
# Round 997 two large crickets meet  [3175 5282] [0.37542864 0.62457136]
# Round 998 a small meets a large    [3176 5290] [0.37514765 0.62485235]
# Round 999 two large crickets meet  [3176 5296] [0.37488196 0.62511804]
# Round 1000 a small meets a large    [3177 5304] [0.37460205 0.62539795]

# %% [markdown]
# The above simulation displays, after each encounter, the number of individuals of each type and the fraction of individuals of each type.   Run the simulation multiple times for different initial conditions.
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 2:</SPAN>**  Answer the following questions.   You do not need to provide code for this problem, but explain your answers.
# <ol>
# <li> How quickly does the total population grow if initally all the crickets are small?
# <li> How quickly does the total population grow if initally all the crickets are large?
# <li> Do the fractions converge to a stable equilibrium in which the fractions of both small and large crickets are nonzero? (To explore convergence you may need to increase the number of encounters simulated.)
# </ol>

# %% [markdown]
# __Answer:__ Question 1: If all the crickets are initially small, the total population grows by 10 crickets per round

# %% [markdown]
# Question 2: If all the crickets are initially large, the total population grows by 6 crickets each round. Therefore, starting with all small crickets yields a faster population growth.

# %% [markdown]
# Question 3: Yes. The fraction of small crickets converges to roughly .37 and the fraction of large crickets converges to roughly .62

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 2</SPAN>**

# %% [markdown]
# The code given next is essentially the same as above.  One difference is a time variable is added such that the average rate that an individual cricket has encounters is proportional to the total number of crickets.  This results in exponential growth of the population with time.    Another difference is that population sizes are saved and plotted.

# %%
# Stochastic simulation of replicator dynamics for cricket game
# Time is scaled so contact rate of each individual is one per unit time
# The evolution trajectory is stored an plotted

F=np.array([[5,1],[8,3]])  # fitness matrix
n_max=100  # maximum number of interactions
n=np.zeros((n_max,2),dtype=float)
time=np.zeros(n_max,dtype=float)

n[0,0], n[0,1] = 10, 1 # initial [number of small crickets, number of large crickets]

for k in range(n_max-1):
    time[k+1]=time[k]+2.0/sum(n[k,:])   # The 2 is here because two individuals make contact at a time
    a=n[k,0]*(n[k,0]-1.0)/((n[k,0]+n[k,1])*(n[k,0]+n[k,1]-1))  # probability both players are type 0
    b=2*n[k,0]*n[k,1]/((n[k,0]+n[k,1])*(n[k,0]+n[k,1]-1.0))  # probability one player of each type
    U=np.random.rand()
    if U<=a:
        n[k+1,:]= n[k,:] + [2*F[0,0],0]
    elif a<U<=a+b:
        n[k+1,:]=n[k,:] + [F[0,1],F[1,0]]
    else:
        n[k+1,:]= n[k,:] + [0,2*F[1,1]]

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.text(1.1,n[80,0], r'small',fontsize=14)
plt.text(1.1,n[80,1], r'large',fontsize=14)
plt.xlabel('time')
plt.ylabel('population size')
plt.title("Numbers of small and large crickets vs. time (simulation)")
# Out:
# Text(0.5, 1.0, 'Numbers of small and large crickets vs. time (simulation)')

# %% [markdown]
# The following code computes the deterministic analog of the cricket evolution.  The basic idea is that if the current population is [n[0], n[1]] then the drift (i.e. the expected rate of increase) of n[0] is n[0]  multiplied by the expected number of small crickets generated by a small cricket if an encounter happens.  That is true because each of the existing small crikets is having encounters at expected rate one.   To calculate the mean number of new small crickets generated by the encounter of a small cricket with a randomly selected other cricket, we use the law of total probability.  The encountered cricket is type zero with probabiity n[0]/(n[0]+n[1]), which results in F[0,0] new crickets of type zero, and the encountered cricket is type one with probability n[1]/(n[0]+n[1]), which results in F[0,1] new crickets of type zero.   Combining we get
# $$
# \dot{n}[0] = n[0]*(F[0,0]*n[0]+F[0,1]*n[1])/(n[0]+n[1])
# $$
# The equation just derived is based on the law of large numbers (LLN).  If the population is fairly large then no one individual plays a major role in the evolution.  Over a small period of time the ratios of small and large crickets is nearly constant, so the number of new crickets of each type in each time slot are nearly independent and identically distributed.   The LLN suggests approximating the sum of number of individuals of each type by the expected numbers of individuals of each type.  That's how we arrive at a deterministic differential equation.
#
# A similar expression holds for the derivative of n[1], and the two equations can be writen in matrix form as
# $$
# \dot{n} = diag(n)*F*n/sum(n)
# $$
# where diag(n) is the diagonal matrix with n[0] and n[1] on the diagonal, and "$*$" represents usual matrix multiplication.   (In the python code below, "$*$" denotes element by element multiplication, which is used instead of creating a diagonal matrix, and np.dot is used for ordinary matrix multiplication.)

# %%
# Deterministic (ODE) replicator dynamics for cricket game
from scipy.integrate import odeint

F=np.array([[5,1],[8,3]])  # fitness matrix

def f(n,t):
    return (n*np.dot(F,n)/sum(n)/1.)

ninit=[10,1]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1.5, 1000)

n=odeint(f,ninit,time)


plt.figure()
plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'small',fontsize=14)
plt.text(1.1,n[800,1], r'large',fontsize=14)
plt.ylabel('population size')
plt.title("Numbers of small and large crickets vs. time (ode prediction)")
# Out:
# Text(0.5, 1.0, 'Numbers of small and large crickets vs. time (ode prediction)')

# %% [markdown]
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 3:</SPAN>** Run the code above and compare the output to the output of the previous code for stochastic evolutionary dynamics.  Try different intial conditions such as [0,4], [4,0], and [10,1]. Comment on how the result of this compares to our previous simulation. Is the behavior similar?

# %% [markdown]
# __Answer__: Yes the behavior seems to be similar for these initial conditions.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 3</SPAN>**

# %% [markdown]
# If we let $\theta[0]=\frac{n[0]}{n[0]+n[1]}$ and $\theta[1]=\frac{n[1]}{n[0]+n[1]}$ then the vector $\theta=\binom{\theta[0]}{\theta[1]}$ describes the fractions of the popuation of each type.  It's entries sum to one.  Using the chain rule of calculus we can derive the following differential equation for $\theta$ from the above ode for $n$:
# $$
# \dot{\theta} = diag(\theta) \left( F\theta - \mathbf{1} \theta^T F \theta \right)
# $$
# where $\mathbf{1}$ is the column vector of ones (the derivation is a bit involved, try deriving it by yourself if interested, but it is not required). The two components of the vector $F \theta$ give the average fitness level of small crickets and large crickets, respectively, in an encounter with a cricket selected randomly from the population.   And $\theta^T F \theta$ is the weighted average of that vector, giving the average fitness over all crickets in the population.   Thus, $\theta[0]$ is increasing exactly when the fitness of small crickets is greater than the average fitness.
#
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 4:</SPAN>**
#
# 1. Modify the above code to integrate the equation for the $\theta$ vector to obtain $\theta$ vs. time.
# To check your answer, compare it to what you get by first computing the trajectory of $n$ and then calculating $\theta$ from $n.$  (The code given above for deterministic evolution of n works for any number of types, not just two types. A problem below involves three types of individuals, so it'd be nice if you could implement your code for computing $\theta$ to work for any number of types.) __Be careful when you write your program, since matrix multiplication in Python can be tricky. Understand "$*$" multiplication and np.dot multiplication first. After each small step, debug, confirm, then proceed.__
# 2. Using the fact that $\theta[1]=1-\theta[0],$  a differential equation can be derived for the variable $\theta[0]$ alone.
# Plot the function $h$ on the interval $[0,1]$ such that $\dot{\theta}[0]=h(\theta[0]).$ Note that the horizontal axis of the graph is $\theta$, the vertical axis is $\dot{\theta}$. (You can just do this
# numerically.  It can also be done algebrically; in fact $h$ is a cubic polynomial, but it is a bit complicated to find the polynomial.)
# 3. What are the zeroes of $h$ (those are the equilibrium points of $\theta[0]$)?  Which of those are stable (in the sense that if $\theta[0]$ is slightly moved away from the equilibrium point, it returns to the equilibrium point)?

# %%
# Your code here
# Stochastic simulation of replicator dynamics for cricket game
# Time is scaled so contact rate of each individual is one per unit time
# The evolution trajectory is stored an plotted
print('Question 1:')
F=np.array([[5,1],[8,3]])  # fitness matrix
ninit=[4,4]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1, 1000)

theta0 = (ninit[0])/(ninit[0] + ninit[1])
theta1 = (ninit[1])/(ninit[0] + ninit[1])
theta = [theta0, theta1]



def f(initial, time):
    diagtheta = np.array([[initial[0], 0], [0, initial[1]]])
    ftheta = np.dot(F, initial)
    theta_transpose = np.array([[initial[0],initial[1]],[initial[0],initial[1]]])
    second_term = np.dot(ftheta, theta_transpose)
    final = np.dot(diagtheta, ftheta-second_term)
    return final

n=odeint(f,theta,time)


plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'small',fontsize=14)
plt.text(1.1,n[800,1], r'large',fontsize=14)
plt.ylabel('Theta')
plt.title("Numbers of small and large crickets vs. time (ode prediction)")


theta2 = []
def g(t):
    return t**3 + t**2 - 2*t
for i in (time):
    theta2.append(g(i))
    
plt.figure()
plt.plot(time,theta2,'blue')
# Out:
# Question 1:

# %% [markdown]
# __Answer:__ Question 3: There is a zero at t = 0 and t = 1 because there are maximums on the graph of the derivative. It is stable for t = 0.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 4</SPAN>**

# %% [markdown]
# The overall behavior in evolutionary games depends heavily on the fitness matrix $F.$   Another choice of $F$ corresponds to the so-called doves and hawks evolution game, for which the fitness matrix is
# $$\begin{array}{c|cc}  & dove & hawk  \\ \hline
#     dove & 3 & 1  \\
#     hawk & 5 & 0
#     \end{array}$$
# or by a fitness matrix
# $$F=\left( \begin{array}{cc}  3 & 1 \\ 5 & 0  \end{array}\right).$$   Think of the doves and hawks as two types of birds that need to share resources, such as food.  (The hawks are so aggressive that they attack the doves).  A dove has higher fitness, 3, against another dove than against a hawk, 1.  A hawk has a high fitness against a dove (5) but zero fitness against another hawk, because the hawks fight over their resources.
#
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 5:</SPAN>**
#
# 1. Repeat the deterministic (ode) approach above, but now for the doves and hawks evolution game.   You can use either the random or deterministic evolution equations for the numerical analysis.
# 2. Comment and verify your assertions about equilibrium behavior by finding a differential equation for $\theta[0]$ and exploring its equilbrium points and their stability.

# %%
# Your code here
# Stochastic simulation of replicator dynamics for cricket game
# Time is scaled so contact rate of each individual is one per unit time
# The evolution trajectory is stored an plotted
print('Question 1:')
F=np.array([[3,1],[5,0]])  # fitness matrix
ninit=[4,4]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1, 1000)

theta0 = (ninit[0])/(ninit[0] + ninit[1])
theta1 = (ninit[1])/(ninit[0] + ninit[1])
theta = [theta0, theta1]



def f(initial, time):
    diagtheta = np.array([[initial[0], 0], [0, initial[1]]])
    ftheta = np.dot(F, initial)
    theta_transpose = np.array([[initial[0],initial[1]],[initial[0],initial[1]]])
    second_term = np.dot(ftheta, theta_transpose)
    final = np.dot(diagtheta, ftheta-second_term)
    return final

n=odeint(f,theta,time)


plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'dove',fontsize=14)
plt.text(1.1,n[800,1], r'hawk',fontsize=14)
plt.ylabel('Theta')
plt.title("Numbers of Doves and Hawks vs. time (ode prediction)")

theta2 = []
def g(t):
    return 3*t**3 - 4*t**2 + t
for i in (time):
    theta2.append(g(i))
    
plt.figure()
plt.plot(time,theta2,'blue')
# Out:
# Question 1:

# %% [markdown]
# __Answer__: There are equilibrium points at 0 and 1.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 5</SPAN>**

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 6:</SPAN>**  Find a 3x3 fitness matrix $F$ and an initial condition for an evolutionary game with three types of individuals such that the solution $\theta$ has a limit cycle, not just converging to a limit point.  Does the limit cycle depend on the intial state for your fitness matrix?
#
# Hint 1: Adapt the code you wrote for Problem 4.
#
# Hint 2: Solve this problem by trial and error, i.e. trying different values of the entries in the fitness matrix. Think of the three types of individuals as three kinds of animals. What kind of relationship among these three animals would likely to cause an oscillating population for each animal?

# %%
# Your code here
F = np.array([[2,-6,6],[6,2,-6],[-6,6,1]]) #fitness matrix
ninit=[1/3., 1/3., 1/3.]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,15, 1000)

theta0 = (ninit[0])/(ninit[0] + ninit[1] + ninit[2])
theta1 = (ninit[1])/(ninit[0] + ninit[1] + ninit[2])
theta2 = (ninit[2])/(ninit[0] + ninit[1] + ninit[2])
theta = [theta0, theta1, theta2]

def f(initial, time):
    diagtheta = np.array([[initial[0], 0, 0], [0, initial[1], 0], [0, 0, initial[2]]])
    ftheta = np.dot(F, initial)
    theta_transpose = np.array([[initial[0],initial[1], initial[2]],[initial[0],initial[1], initial[2]], [initial[0],initial[1], initial[2]]])
    second_term = np.dot(ftheta, theta_transpose)
    final = np.dot(diagtheta, ftheta-second_term)
    return final

n = odeint(f,theta,time)

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.plot(time,n[:,2],'green')
plt.xlabel('time')
# plt.text(1.1,n[800,0], r'small',fontsize=14)
# plt.text(1.1,n[800,1], r'large',fontsize=14)
plt.ylabel('Theta')
# Out:
# Text(0, 0.5, 'Theta')

# %% [markdown]
# __Answer__: After trying different initial states, the limit cycle does not depend on it

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 6</SPAN>**

# %% [markdown]
# For this week's lab, please answer all questions 1-6.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ## Academic Integrity Statement ##
#
# By submitting the lab with this statement, you declare you have written up the lab entirely by yourself, including both code and markdown cells. You also agree that you should not share your code with anyone else. Any violation of the academic integrity requirement may cause an academic integrity report to be filed that could go into your student record. See <a href="https://provost.illinois.edu/policies/policies/academic-integrity/students-quick-reference-guide-to-academic-integrity/">Students' Quick Reference Guide to Academic Integrity</a> for more information.
